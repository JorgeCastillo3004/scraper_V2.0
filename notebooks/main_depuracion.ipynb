# %% [markdown]
# ### Import libraries and modules.

# %%
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.firefox.service import Service
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium import webdriver
from datetime import datetime
import random
import time
import json
import re
import os
from selenium.webdriver.support.ui import Select
from datetime import date, timedelta
import string

import importlib
import os
# import sys
# sys.path.append('modules')
from common_functions import *
from data_base import *
from milestone1 import *
from milestone2 import *
from milestone3 import *
from milestone4 import *
from milestone6 import *
from milestone7 import *
from milestone8 import *
from main import *

# Load the autoreload extension
# %load_ext autoreload

# Enable autoreload for all modules
# %autoreload 2

# from flashcore_extraction import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Load Flashcore website and login

# %%
driver = launch_navigator('https://www.flashscore.com', headless = False)
# login(driver, email_= "jignacio@jweglobal.com", password_ = "Caracas5050@\n")
print('SESSION_ID:', driver.session_id)                                                                                              
print('EXECUTOR_URL:', driver.command_executor._url)
# Out:
# SESSION_ID: 29153a73-59da-42b5-a542-769189e5bc8a
# EXECUTOR_URL: http://localhost:35655

# %% [markdown]
# # News extraction

# %%
import os 
os.path.isfile('check_points/sports_url_m1.json')
# Out:
# True

# %%
# ["TENNIS", "BASKETBALL","AMERICAN_SPORTS","HOCKEY"]
# extraccion de noticias
main_extract_news(driver, ['FOOTBALL','TENNIS','GOLF'], MAX_OLDER_DATE_ALLOWED = 1)
# Out:
# ######################################################################################################
# #                                           NEWS: FOOTBALL                                           #
# ######################################################################################################
#
# https://www.flashscore.com/news/football/
#
#
# ######################################################################################################
# #                                            NEWS: TENNIS                                            #
# ######################################################################################################
#
# https://www.flashscore.com/news/tennis/
#
#
# ######################################################################################################
# #                                             NEWS: GOLF                                             #
# ######################################################################################################
#
# https://www.flashscore.com/news/golf/

# %% [markdown]
# # Leagues creation

# %%
# create_leagues(driver, ["FOOTBALL", "BASKETBALL","BASEBALL", "AM. FOOTBALL", "HOCKEY", "TENNIS","GOLF", "BOXING",'FORMULA 1'])
# creacion de ligas "HOCKEY", "TENNIS","GOLF"
create_leagues(driver, ["BASKETBALL","BASEBALL", "AM._FOOTBALL"])
# Out:
# #######################################################################################################
# #                                        Filling country table                                        #
# #######################################################################################################
#
# DB reconnected
# ⚠️ País 'ARUBA' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'AFGHANISTAN' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'ANGOLA' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'ANGUILLA' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'ÅLAND ISLANDS' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'ALBANIA' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'ANDORRA' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'UNITED ARAB EMIRATES' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'ARGENTINA' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'ARMENIA' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'AMERICAN SAMOA' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'ANTARCTICA' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'FRENCH SOUTHERN TERRITORIES' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'ANTIGUA AND BARBUDA' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'AUSTRALIA' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'AUSTRIA' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'AZERBAIJAN' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'BURUNDI' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'BELGIUM' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'BENIN' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'BONAIRE' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'BURKINA FASO' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'BANGLADESH' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'BULGARIA' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'BAHRAIN' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'BAHAMAS' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'BOSNIA AND HERZEGOVINA' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'SAINT BARTHÉLEMY' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'BELARUS' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'BELIZE' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'BERMUDA' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'BOLIVIA' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'BRAZIL' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'BARBADOS' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'BRUNEI DARUSSALAM' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'BHUTAN' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'BOUVET ISLAND' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'BOTSWANA' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'CENTRAL AFRICAN REPUBLIC' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'CANADA' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'COCOS (KEELING) ISLANDS' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'SWITZERLAND' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'CHILE' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'CHINA' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'CÔTE D'IVOIRE' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'CAMEROON' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'CONGO' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'CONGO' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'COOK ISLANDS' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'COLOMBIA' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'COMOROS' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'CABO VERDE' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'COSTA RICA' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'CUBA' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'CURAÇAO' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País '
ISLANDS' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'URUGUAY' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'UNITED STATES' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'UZBEKISTAN' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'HOLY SEE (VATICAN CITY STATE)' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'SAINT VINCENT AND THE GRENADINES' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'VENEZUELA' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'VIRGIN ISLANDS' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'VIRGIN ISLANDS' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'VIET NAM' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'VANUATU' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'WALLIS AND FUTUNA' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'SAMOA' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'YEMEN' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'SOUTH AFRICA' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'ZAMBIA' ya existe en la base de datos. Se omite la inserción.
# ⚠️ País 'ZIMBABWE' ya existe en la base de datos. Se omite la inserción.
#
#
# ######################################################################################################
# #                                             BASKETBALL                                             #
# ######################################################################################################
#
# *** ARGENTINA_LIGA-A ***                                    1 / 14
#
#
# #######################################################################################################
# #                                             LEAGUE INFO                                             #
# #######################################################################################################
#
# {'sport_id': 'c22f15b1-7900-4751-a936-2e2585be7267', 'league_id': '510188a7-663e-4f1e-9497-6573415b99d7', 'season_id': '5b96b80c-b5a1-4cbd-99e3-1d5aa14b3b83', 'sport': 'BASKETBALL', 'league_country': 'ARGENTINA', 'league_name': 'Liga A', 'season_name': '2025/2026', 'league_logo': 'images/logos/argentina_liga_a_ajzb6.jpg', 'league_name_i18n': '', 'season_end': datetime.datetime(2026, 3, 4, 23, 11, 27, 627633), 'season_start': datetime.datetime(2026, 3, 4, 23, 11, 27, 627639), 'image_url': 'https://static.flashscore.com/res/image/data/pKqwkgW1-zJqb6Tjo.png', 'image_path': 'images/logos/argentina_liga_a_ajzb6.jpg'}
# {'sport_id': 'c22f15b1-7900-4751-a936-2e2585be7267', 'league_id': '510188a7-663e-4f1e-9497-6573415b99d7', 'season_id': '5b96b80c-b5a1-4cbd-99e3-1d5aa14b3b83', 'sport': 'BASKETBALL', 'league_country': 'ARGENTINA', 'league_name': 'Liga A', 'season_name': '2025/2026', 'league_logo': 'images/logos/argentina_liga_a_ajzb6.jpg', 'league_name_i18n': '', 'season_end': datetime.datetime(2026, 3, 4, 23, 11, 27, 627633), 'season_start': datetime.datetime(2026, 3, 4, 23, 11, 27, 627639), 'image_url': 'https://static.flashscore.com/res/image/data/pKqwkgW1-zJqb6Tjo.png', 'image_path': 'images/logos/argentina_liga_a_ajzb6.jpg', 'country_id': '1gg2cou9izg4xcqln'}
# key db  c22f15b1-7900-4751-a936-2e2585be7267_1gg2cou9izg4xcqln_Liga A
# key json:  ARGENTINA_Liga A
# dict_leagues_ready_db
# ################################################################################
#
#
# ######################
# #        READY       #
# ######################
#
# ARGENTINA_Liga A
# League id from db:  29991f9a-f5a9-4548-b62a-090c7add56c5
# LEAGUE ID USED FOR SEASON:  29991f9a-f5a9-4548-b62a-090c7add56c5
# list_seasons:  ['2025/2026']
# *** BRAZIL_NBB ***                                          2 / 14
#
#
# #######################################################################################################
# #                                             LEAGUE INFO                                             #
# #######################################################################################################
#
# {'sport_id': 'c22f15b1-7900-4751-a936-2e2585be7267', 'league_id': '0023eb17-714b-480f-b9b8-64ce6697d38b', 'season_id': '5f266e10-4f1a-4705-8702-60d5fccd3e42', 'sport': 'BASKETBALL', 'league_country': 'BRAZIL', 'league_name': 'NBB', 'season_name': '2025/2026', 'league_logo': 'images/logos/brazil_nbb_kpxf9.jpg', 'league_name_i18n': '', 'season_end': datetime.datetime(2026, 3, 4, 23, 11, 36, 172825), 'season_start': datetime.datetime(2026, 3, 4, 23, 11, 36, 172834), 'image_url': 'https://static.flashscore.com/res/image/data/jkQF3EkD-Yy6kvV6B.png', 'image_path': 'images/logos/brazil_nbb_kpxf9.jpg'}
# {'sport_id': 'c22f15b1-7900-4751-a936-2e2585be7267', 'league_id': '0023eb17-714b-480f-b9b8-64ce6697d38b', 'season_id': '5f266e10-4f1a-4705-8702-60d5fccd3e42', 'sport': 'BASKETBALL', 'league_country': 'BRAZIL', 'league_name': 'NBB', 'season_name': '2025/2026', 'league_logo': 'images/logos/brazil_nbb_kpxf9.jpg', 'league_name_i18n': '', 'season_end': datetime.datetime(2026, 3, 4, 23, 11, 36, 172825), 'season_start': datetime.datetime(2026, 3, 4, 23, 11, 36, 172834), 'image_url': 'https://static.flashscore.com/res/image/data/jkQF3EkD-Yy6kvV6B.png', 'image_path': 'images/logos/brazil_nbb_kpxf9.jpg', 'country_id': '2b1t9zgj0xl2vqskc'}
# key db  c22f15b1-7900-4751-a936-2e2585be7267
jpg', 'league_name_i18n': '', 'season_end': datetime.datetime(2026, 3, 4, 23, 13, 13, 560710), 'season_start': datetime.datetime(2026, 3, 4, 23, 13, 13, 560719), 'image_url': 'https://static.flashscore.com/res/image/data/h6xr9GhU-ng3CJnV9.png', 'image_path': 'images/logos/venezuela_superliga_tvso3.jpg', 'country_id': '30swtxtz71s2w9zag'}
# key db  c22f15b1-7900-4751-a936-2e2585be7267_30swtxtz71s2w9zag_Superliga
# key json:  VENEZUELA_Superliga
# dict_leagues_ready_db
# ################################################################################
#
#
# ######################
# #        READY       #
# ######################
#
# VENEZUELA_Superliga
# League id from db:  d45d48c9-a9dd-4d59-aaa4-f1473d731ea7
# LEAGUE ID USED FOR SEASON:  d45d48c9-a9dd-4d59-aaa4-f1473d731ea7
# list_seasons:  ['2026']
# *** EUROPE_EUROBASKET ***                                   10 / 14
#
#
# #######################################################################################################
# #                                             LEAGUE INFO                                             #
# #######################################################################################################
#
# {'sport_id': 'c22f15b1-7900-4751-a936-2e2585be7267', 'league_id': '68c5eb23-d953-47fa-b91e-16b2f554ef12', 'season_id': '3218019a-76fe-448e-ac89-898d3ca553fe', 'sport': 'BASKETBALL', 'league_country': 'EUROPE', 'league_name': 'EuroBasket', 'season_name': '2029', 'league_logo': 'images/logos/europe_eurobasket_ufwv1.jpg', 'league_name_i18n': '', 'season_end': datetime.datetime(2026, 3, 4, 23, 13, 23, 989678), 'season_start': datetime.datetime(2026, 3, 4, 23, 13, 23, 989687), 'image_url': 'https://static.flashscore.com/res/image/data/08cqtfhD-KzXabVwE.png', 'image_path': 'images/logos/europe_eurobasket_ufwv1.jpg'}
# {'sport_id': 'c22f15b1-7900-4751-a936-2e2585be7267', 'league_id': '68c5eb23-d953-47fa-b91e-16b2f554ef12', 'season_id': '3218019a-76fe-448e-ac89-898d3ca553fe', 'sport': 'BASKETBALL', 'league_country': 'EUROPE', 'league_name': 'EuroBasket', 'season_name': '2029', 'league_logo': 'images/logos/europe_eurobasket_ufwv1.jpg', 'league_name_i18n': '', 'season_end': datetime.datetime(2026, 3, 4, 23, 13, 23, 989678), 'season_start': datetime.datetime(2026, 3, 4, 23, 13, 23, 989687), 'image_url': 'https://static.flashscore.com/res/image/data/08cqtfhD-KzXabVwE.png', 'image_path': 'images/logos/europe_eurobasket_ufwv1.jpg', 'country_id': '4ex9xdkdu6chrpa20'}
# key db  c22f15b1-7900-4751-a936-2e2585be7267_4ex9xdkdu6chrpa20_EuroBasket
# key json:  EUROPE_EuroBasket
# dict_leagues_ready_db
# ################################################################################
#
#
# ######################
# #        READY       #
# ######################
#
# EUROPE_EuroBasket
# League id from db:  13f58342-569a-409d-aaa5-936ace519055
# LEAGUE ID USED FOR SEASON:  13f58342-569a-409d-aaa5-936ace519055
# list_seasons:  ['2029']
# *** EUROPE_EUROLEAGUE ***                                   11 / 14
#
#
# #######################################################################################################
# #                                             LEAGUE INFO                                             #
# #######################################################################################################
#
# {'sport_id': 'c22f15b1-7900-4751-a936-2e2585be7267', 'league_id': 'a5d8426e-4de3-4ae4-a101-3f83d3639759', 'season_id': 'dec2583e-9eb7-4534-adb6-8d7cabce0b87', 'sport': 'BASKETBALL', 'league_country': 'EUROPE', 'league_name': 'Euroleague', 'season_name': '2025/2026', 'league_logo': 'images/logos/europe_euroleague_ltic9.jpg', 'league_name_i18n': '', 'season_end': datetime.datetime(2026, 3, 4, 23, 13, 34, 760748), 'season_start': datetime.datetime(2026, 3, 4, 23, 13, 34, 760756), 'image_url': 'https://static.flashscore.com/res/image/data/8dVwmZmd-CUgbd9DB.png', 'image_path': 'images/logos/europe_euroleague_ltic9.jpg'}
# {'sport_id': 'c22f15b1-7900-4751-a936-2e2585be7267', 'league_id': 'a5d8426e-4de3-4ae4-a101-3f83d3639759', 'season_id': 'dec2583e-9eb7-4534-adb6-8d7cabce0b87', 'sport': 'BASKETBALL', 'league_country': 'EUROPE', 'league_name': 'Euroleague', 'season_name': '2025/2026', 'league_logo': 'images/logos/europe_euroleague_ltic9.jpg', 'league_name_i18n': '', 'season_end': datetime.datetime(2026, 3, 4, 23, 13, 34, 760748), 'season_start': datetime.datetime(2026, 3, 4, 23, 13, 34, 760756), 'image_url': 'https://static.flashscore.com/res/image/data/8dVwmZmd-CUgbd9DB.png', 'image_path': 'images/logos/europe_euroleague_ltic9.jpg', 'country_id': '4ex9xdkdu6chrpa20'}
# key db  c22f15b1-7900-4751-a936-2e2585be7267_4ex9xdkdu6chrpa20_Euroleague
# key json:  EUROPE_Euroleague
# dict_leagues_ready_db
# ################################################################################
#
#
# ######################
# #        READY       #
# ######################
#
# EUROPE_Euroleague
# League id from db:  dbcad404-ad94-4773-9f8d-4d673cf05b86
# LEAGUE ID USED FOR SEASON:  dbcad404-ad94-4773-9f8d-4d673cf05b86
# list_seasons:  ['2025/2026']
# *** EUROPE_EUROCUP ***                                      12 / 14
#
#
# #######################################################################################################
# #                                             LEAGUE INFO                                             #
# #######################################################################################################
#
# {'sport_id': 'c22f15b1-7900-4751-a936-2e2585be7267', 'league_id': 'fedde6cb-1e58-47c1-982c-844e66d24787', 'season_id': 'f0b1f418-9c82-48e0-90e1-93d0809281d8', 'sport': 'BASKETBALL', 'league_country': 'EUROPE', 'league_name': 'Eurocup', 'season_name': '2025/2026', 'league_logo': 'images/logos/europe_eurocup_choz6.jpg', 'league_name_i18n': '', 'season_end': datetime.datetime(2026, 3, 4, 23, 13, 45, 281926), 'season_start': datetime.datetime(2026, 3, 4, 23, 13, 45, 281934), 'image_url': 'https://static.flashscore.com/res/image/data/Gh5e97ld-4xEKMg2D.png', 'image_path': 'images/logos/europe_eurocup_choz6.jpg'}
# {'sport_id': 'c22f15b1-7900-4751-a936-2e2585be7267', 'league_id': 'fedde6cb-1e58-47c1-982c-844e66d24787', 'season_id': 'f0b1f418-9c82-48e0-90e1-93d0809281d8', 'sport': 'BASKETBALL', 'league_country': 'EUROPE', 'league_name': 'Eurocup', 'season_name': '2025/2026', 'league_logo': 'images/logos/europe_eurocup_choz6.jpg', 'league_name_i18n': '', 'season_end': datetime.datetime(2026, 3, 4, 23, 13, 45, 281926), 'season_start': datetime.datetime(2026, 3, 4, 23, 13, 45, 281934), 'image_url': 'https://static.flashscore.com/res/image/data/Gh5e97ld-4xEKMg2D.png', 'image_path': 'images/logos/europe_eurocup_choz6.jpg', 'country_id': '4ex9xdkdu6chrpa20'}
# key db  c22f15b1-7900-4751-a936-2e2585be7267_4ex9xdkdu6chrpa20_Eurocup
# key json:  EUROPE_Eurocup
# dict_leagues_ready_db
# ################################################################################
#
#
# ######################
# #        READY       #
# ######################
#
# EUROPE_Eurocup
# League id from db:  b909979b-8646-45e2-a8ed-697d6591787b
# LEAGUE ID USED FOR SEASON:  b909979b-8646-45e2-a8ed-697d6591787b
# list_seasons:  ['2025/2026']
# *** EUROPE_CHAMPIONS-LEAGUE ***                             13 / 14
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 3
#       1 # create_leagues(driver, ["FOOTBALL", "BASKETBALL","BASEBALL", "AM. FOOTBALL", "HOCKEY", "TENNIS","GOLF", "BOXING",'FORMULA 1'])
#       2 # creacion de ligas "HOCKEY", "TENNIS","GOLF"
# ----> 3 create_leagues(driver, ["BASKETBALL","BASEBALL", "AM._FOOTBALL"])
#
# File ~/work_2026/milestone2.py:575, in create_leagues(driver, list_sports)
#     573     league_info = get_league_data_boxing(driver, league_name, sport_name)
#     574 else:
# --> 575     league_info = get_league_data(driver, league_name, sport_name)
#     577 print_section("LEAGUE INFO")
#     578 print(league_info)
#
# File ~/work_2026/milestone2.py:68, in get_league_data(driver, league_team, sport_name)
#      66 sport = block_ligue_team.find_element(By.XPATH, './/h2[@class= "breadcrumb"]/a[1]').text
#      67 league_country = block_ligue_team.find_element(By.XPATH, './/h2[@class= "breadcrumb"]/a[2]').text
# ---> 68 league_name = block_ligue_team.find_element(By.CLASS_NAME,'heading__title').text
#      69 season_name = block_ligue_team.find_element(By.CLASS_NAME, 'heading__info').text
#      70 image_url = block_ligue_team.find_element(By.XPATH, './/div[@class= "heading"]/img').get_attribute('src')
#
# File ~/env/sports_env/lib/python3.10/site-packages/selenium/webdriver/remote/webelement.py:417, in WebElement.find_element(self, by, value)
#     414     by = By.CSS_SELECTOR
#     415     value = f'[name="{value}"]'
# --> 417 return self._execute(Command.FIND_CHILD_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~/env/sports_env/lib/python3.10/site-packages/selenium/webdriver/remote/webelement.py:395, in WebElement._execute(self, command, params)
#     393     params = {}
#     394 params["id"] = self._id
# --> 395 return self._parent.execute(command, params)
#
# File ~/env/sports_env/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:352, in WebDriver.execute(self, driver_command, params)
#     349     elif "sessionId" not in params:
#     350         params["sessionId"] = self.session_id
# --> 352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
#     354     self.error_handler.check_response(response)
#
# File ~/env/sports_env/lib/python3.10/site-packages/selenium/webdriver/remote/remote_connection.py:306, in RemoteConnection.execute(self, command, params)
#     304 trimmed = self._trim_large_entries(params)
#     305 LOGGER.debug("%s %s %s", command_info[0], url, str(trimmed))
# --> 306 return self._request(command_info[0], url, body=data)
#
# File ~/env/sports_env/lib/python3.10/site-packages/selenium/webdriver/remote/remote_connection.py:326, in RemoteConnection._request(self, method, url, body)
#     323     body = None
#     325 if self.keep_alive:
# --> 326     response = self._conn.request(method, url, body=body, headers=headers)
#     327     statuscode = response.status
#     328 else:
#
# File ~/env/sports_env/lib/python3.10/site-packages/urllib3/_request_methods.py:143, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     135     return self.request_encode_url(
#     136         method,
#     137         url,
#    (...)
#     140         **urlopen_kw,
#     141     )
#     142 else:
# --> 143     return self.request_encode_body(
#     144         method, url, fields=fields, headers=headers, **urlopen_kw
#     145     )
#
# File ~/env/sports_env/lib/python3.10/site-packages/urllib3/_request_methods.py:278, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     274     extra_kw["headers"].setdefault("Content-Type", content_type)
#     276 extra_kw.update(urlopen_kw)
# --> 278 return self.urlopen(method, url, **extra_kw)
#
# File ~/env/sports_env/lib/python3.10/site-packages/urllib3/poolmanager.py:443, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     441     response = conn.urlopen(method, url, **kw)
#     442 else:
# --> 443     response = conn.urlopen(method, u.request_uri, **kw)
#     445 redirect_location = redirect and response.get_redirect_location()
#     446 if not redirect_location:
#
# File ~/env/sports_env/lib/python3.10/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/env/sports_env/lib/python3.10/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/env/sports_env/lib/python3.10/site-packages/urllib3/connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File /usr/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File /usr/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /usr/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /usr/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# # Teams creation

# %%
# creacion de equipos
teams_creation(driver, ["FOOTBALL","BASKETBALL","BASEBALL", "AM._FOOTBALL"])
# Out:
# DB reconnected
#
#
# #######################################################################################################
# #                                           SPORT: FOOTBALL                                           #
# #######################################################################################################
#
# [RESUME] Liga: AFRICA_World Cup | Equipo: New Zealand
# [SKIP LEAGUE] ARGENTINA_Liga Profesional
# [SKIP LEAGUE] ARGENTINA_Copa de la Liga Profesional
# [SKIP LEAGUE] BELGIUM_Jupiler Pro League
# [SKIP LEAGUE] BOLIVIA_Division Profesional
# [SKIP LEAGUE] BRAZIL_Serie A Betano
# [SKIP LEAGUE] CHILE_Liga de Primera
# [SKIP LEAGUE] CHINA_Super League
# [SKIP LEAGUE] COLOMBIA_Primera A
# [SKIP LEAGUE] COSTA RICA_Primera Division
# [SKIP LEAGUE] ECUADOR_Liga Pro
# [SKIP LEAGUE] ENGLAND_Premier League
# [SKIP LEAGUE] FRANCE_Ligue 1
# [SKIP LEAGUE] GERMANY_Bundesliga
# [SKIP LEAGUE] ITALY_Serie A
# [SKIP LEAGUE] MEXICO_Liga MX
# [SKIP LEAGUE] NETHERLANDS_Eredivisie
# [SKIP LEAGUE] PANAMA_LPF
# [SKIP LEAGUE] PARAGUAY_Copa de Primera
# [SKIP LEAGUE] PERU_Liga 1
# [SKIP LEAGUE] QATAR_QSL
# [SKIP LEAGUE] RUSSIA_Premier League
# [SKIP LEAGUE] SPAIN_LaLiga
# [SKIP LEAGUE] SPAIN_Copa del Rey
# [SKIP LEAGUE] SPAIN_Copa Federacion
# [SKIP LEAGUE] SPAIN_Super Cup
# [SKIP LEAGUE] TURKEY_Super Lig
# [SKIP LEAGUE] UNITED ARAB EMIRATES_UAE League
# [SKIP LEAGUE] URUGUAY_Liga AUF Uruguaya
# [SKIP LEAGUE] USA_MLS
# [SKIP LEAGUE] VENEZUELA_Liga FUTVE
# [SKIP LEAGUE] AFRICA_Africa Cup of Nations
# ############################## START PROCESS LEAGUE AFRICA_World Cup ##############################
# --
# ##############################  TEAMS FROM LEAGUE AFRICA_World Cup ADDED ##############################
# # TEAMS:  0
# ############################## START PROCESS LEAGUE EUROPE_UEFA Nations League ##############################
# --
# ##############################  TEAMS FROM LEAGUE EUROPE_UEFA Nations League ADDED ##############################
# # TEAMS:  0
# ############################## START PROCESS LEAGUE NORTH & CENTRAL AMERICA_CONCACAF Champions Cup ##############################
# --
# ##############################  TEAMS FROM LEAGUE NORTH & CENTRAL AMERICA_CONCACAF Champions Cup ADDED ##############################
# # TEAMS:  0
# ############################## START PROCESS LEAGUE SOUTH AMERICA_Copa Libertadores ##############################
# --
# ##############################  TEAMS FROM LEAGUE SOUTH AMERICA_Copa Libertadores ADDED ##############################
# # TEAMS:  0
#
#
# #######################################################################################################
# #                                          SPORT: BASKETBALL                                          #
# #######################################################################################################
#
# ############################## START PROCESS LEAGUE BRAZIL_NBB ##############################
# --
# ##############################  TEAMS FROM LEAGUE BRAZIL_NBB ADDED ##############################
# # TEAMS:  0
# ############################## START PROCESS LEAGUE CHINA_CBA ##############################
# --
# ##############################  TEAMS FROM LEAGUE CHINA_CBA ADDED ##############################
# # TEAMS:  0
# ############################## START PROCESS LEAGUE FRANCE_LNB ##############################
# --
# ##############################  TEAMS FROM LEAGUE FRANCE_LNB ADDED ##############################
# # TEAMS:  0
# ############################## START PROCESS LEAGUE ITALY_Lega A ##############################
# --
# ##############################  TEAMS FROM LEAGUE ITALY_Lega A ADDED ##############################
# # TEAMS:  0
# ############################## START PROCESS LEAGUE SPAIN_ACB ##############################
# --
# ##############################  TEAMS FROM LEAGUE SPAIN_ACB ADDED ##############################
# # TEAMS:  0
# ############################## START PROCESS LEAGUE TURKEY_Super Lig ##############################
# --
# ##############################  TEAMS FROM LEAGUE TURKEY_Super Lig ADDED ##############################
# # TEAMS:  0
# ############################## START PROCESS LEAGUE USA_NBA ##############################
# --
# ##############################  TEAMS FROM LEAGUE USA_NBA ADDED ##############################
# # TEAMS:  0
# ############################## START PROCESS LEAGUE VENEZUELA_Superliga ##############################
# --
# ##############################  TEAMS FROM LEAGUE VENEZUELA_Superliga ADDED ##############################
# # TEAMS:  0
#
#
# #######################################################################################################
# #                                           SPORT: BASEBALL                                           #
# #######################################################################################################
#
#
#
# #######################################################################################################
# #                                         SPORT: AM._FOOTBALL                                         #
# #######################################################################################################
#
# ############################## START PROCESS LEAGUE CANADA_CFL ##############################
# --
# ##############################  TEAMS FROM LEAGUE CANADA_CFL ADDED ##############################
# # TEAMS:  0
# ############################## START PROCESS LEAGUE USA_NFL ##############################
# --
# ##############################  TEAMS FROM LEAGUE USA_NFL ADDED ##############################
# # TEAMS:  0
#
#
# #######################################################################################################
# #                                            SPORT: HOCKEY                                            #
# #######################################################################################################
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 2
#       1 # creacion de equipos
# ----> 2 teams_creation(driver, ["FOOTBALL","BASKETBALL","BASEBALL", "AM._FOOTBALL", "HOCKEY", "TENNIS","GOLF"])
#
# File ~/work_2026/milestone3.py:175, in teams_creation(driver, list_sports)
#     172 if resume_league:
#     173 	print(f"[RESUME] Liga: {resume_league} | Equipo: {resume_team}")
# --> 175 for country_league, legue_info in leagues_info_json[sport_name].items():
#     176 	add_league_info(sport_name, sport_id, country_league, legue_info)
#     178 	# RESUME — nivel liga: saltar hasta llegar al checkpoint
#
# KeyError: 'HOCKEY'

# %% [markdown]
# # Get results.

# %%
# from milestone4 import *
# obtencion de resultados de partidos jugados
# results_fixtures_extraction(driver, ["FOOTBALL","BASKETBALL","BASEBALL", "AM._FOOTBALL"], name_section = 'results')
# Out:
# DB reconnected
#
#
# #######################################################################################################
# #                                               RESULTS                                               #
# #######################################################################################################
#
#
#
# ######################################################################################################
# #                                              FOOTBALL                                              #
# ######################################################################################################
#
# [SKIP] ARGENTINA_Liga Profesional — extract_results.extract=false
# [SKIP] ARGENTINA_Copa de la Liga Profesional — extract_results.extract=false
# [SKIP] BELGIUM_Jupiler Pro League — extract_results.extract=false
# [SKIP] BOLIVIA_Division Profesional — extract_results.extract=false
# [SKIP] BRAZIL_Serie A Betano — extract_results.extract=false
#
#
# #######################################################################################################
# #                  LEAGUE: CHILE_Liga de Primera, MATCH NUMBER: 21 TEAMS CREATED: 18                  #
# #######################################################################################################
#
# ['ROUND_2.json', 'ROUND_3.json', 'ROUND_4.json', 'ROUND_5.json', 'ROUND_6.json']
#
# Current file:  check_points/results/CHILE_Liga de Primera/ROUND_2.json
#
#
# #######################################################################################################
# #                  NEW EVENT check_points/results/CHILE_Liga de Primera/ROUND_2.json                  #
# #######################################################################################################
#
#
#
# #######################################################################################################
# #               https://www.flashscore.com/match/YyD4Fv0N/#/match-summary/match-summary               #
# #######################################################################################################
#
# WAITING DETAILS
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/work_2026/milestone4.py:393, in wait_load_details(driver, url_details)
#     392 try:
# --> 393     wait.until(EC.visibility_of_element_located((By.XPATH, '//div[@class="matchInfoData"]')))
#     394 except:
#
# File ~/env/sports_env/lib/python3.10/site-packages/selenium/webdriver/support/wait.py:102, in WebDriverWait.until(self, method, message)
#     101     stacktrace = getattr(exc, "stacktrace", None)
# --> 102 time.sleep(self._poll)
#     103 if time.monotonic() > end_time:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# ConnectionResetError                      Traceback (most recent call last)
# File ~/env/sports_env/lib/python3.10/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File ~/env/sports_env/lib/python3.10/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File ~/env/sports_env/lib/python3.10/site-packages/urllib3/connection.py:507, in HTTPConnection.getresponse(self)
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#
# File /usr/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1374 try:
# -> 1375     response.begin()
#    1376 except ConnectionError:
#
# File /usr/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File /usr/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#
# File /usr/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     704 try:
# --> 705     return self._sock.recv_into(b)
#     706 except timeout:
#
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# Cell In[11], line 3
#       1 # from milestone4 import *
#       2 # obtencion de resultados de partidos jugados
# ----> 3 results_fixtures_extraction(driver, ["FOOTBALL","BASKETBALL","BASEBALL", "AM._FOOTBALL"], name_section = 'results')
#
# File ~/work_2026/milestone4.py:898, in results_fixtures_extraction(driver, list_sports, name_section, leagues_subset)
#     895         navigate_through_rounds(driver, league_info, section_name = name_section)
#     897     league_checkpoint = league_info[extract_key]
# --> 898     get_complete_match_info(driver, league_info, dict_league, league_checkpoint, leagues_info_json, section=name_section, li_file=li_file)
#     900 # ACTUALIZAR CONTEO DE PARTIDOS EN leagues_info.json
#     901 match_number = get_match_by_league_id(league_info['league_id'])
#
# File ~/work_2026/milestone4.py:561, in get_complete_match_info(driver, league_info, dict_country_league_season, league_checkpoint, leagues_info_json, section, li_file)
#     559 print_section(url_details, space_ = 50)
#     560 print("WAITING DETAILS")
# --> 561 wait_load_details(driver, url_details)
#     562 event_info = get_match_info(driver, event_info)
#     563 print("event_info part 1: ", event_info)
#
# File ~/work_2026/milestone4.py:395, in wait_load_details(driver, url_details)
#     393     wait.until(EC.visibility_of_element_located((By.XPATH, '//div[@class="matchInfoData"]')))
#     394 except:
# --> 395     block_info_after = driver.find_elements(By.XPATH,'//div[@class="matchInfoData"]')
#     397 if len(block_info_before) == 0:
#     398     try:
#
# File ~/env/sports_env/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:778, in WebDriver.find_elements(self, by, value)
#     774     value = f'[name="{value}"]'
#     776 # Return empty list if driver returns null
#     777 # See https://github.com/SeleniumHQ/selenium/issues/4555
# --> 778 return self.execute(Command.FIND_ELEMENTS, {"using": by, "value": value})["value"] or []
#
# File ~/env/sports_env/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:352, in WebDriver.execute(self, driver_command, params)
#     349     elif "sessionId" not in params:
#     350         params["sessionId"] = self.session_id
# --> 352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
#     354     self.error_handler.check_response(response)
#
# File ~/env/sports_env/lib/python3.10/site-packages/selenium/webdriver/remote/remote_connection.py:306, in RemoteConnection.execute(self, command, params)
#     304 trimmed = self._trim_large_entries(params)
#     305 LOGGER.debug("%s %s %s", command_info[0], url, str(trimmed))
# --> 306 return self._request(command_info[0], url, body=data)
#
# File ~/env/sports_env/lib/python3.10/site-packages/selenium/webdriver/remote/remote_connection.py:326, in RemoteConnection._request(self, method, url, body)
#     323     body = None
#     325 if self.keep_alive:
# --> 326     response = self._conn.request(method, url, body=body, headers=headers)
#     327     statuscode = response.status
#     328 else:
#
# File ~/env/sports_env/lib/python3.10/site-packages/urllib3/_request_methods.py:143, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     135     return self.request_encode_url(
#     136         method,
#     137         url,
#    (...)
#     140         **urlopen_kw,
#     141     )
#     142 else:
# --> 143     return self.request_encode_body(
#     144         method, url, fields=fields, headers=headers, **urlopen_kw
#     145     )
#
# File ~/env/sports_env/lib/python3.10/site-packages/urllib3/_request_methods.py:278, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     274     extra_kw["headers"].setdefault("Content-Type", content_type)
#     276 extra_kw.update(urlopen_kw)
# --> 278 return self.urlopen(method, url, **extra_kw)
#
# File ~/env/sports_env/lib/python3.10/site-packages/urllib3/poolmanager.py:443, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     441     response = conn.urlopen(method, url, **kw)
#     442 else:
# --> 443     response = conn.urlopen(method, u.request_uri, **kw)
#     445 redirect_location = redirect and response.get_redirect_location()
#     446 if not redirect_location:
#
# File ~/env/sports_env/lib/python3.10/site-packages/urllib3/connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     840 elif isinstance(new_e, (OSError, HTTPException)):
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#     848 # Keep track of the error for the retry warning.
#
# File ~/env/sports_env/lib/python3.10/site-packages/urllib3/util/retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     471 elif error and self._is_read_error(error):
#     472     # Read retry?
#     473     if read is False or method is None or not self._is_method_retryable(method):
# --> 474         raise reraise(type(error), error, _stacktrace)
#     475     elif read is not None:
#     476         read -= 1
#
# File ~/env/sports_env/lib/python3.10/site-packages/urllib3/util/util.py:38, in reraise(tp, value, tb)
#      36 try:
#      37     if value.__traceback__ is not tb:
# ---> 38         raise value.with_traceback(tb)
#      39     raise value
#      40 finally:
#
# File ~/env/sports_env/lib/python3.10/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/env/sports_env/lib/python3.10/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/env/sports_env/lib/python3.10/site-packages/urllib3/connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File /usr/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File /usr/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /usr/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /usr/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))

# %% [markdown]
# # Get Fixtures

# %%
# creacion de partidos a futuro "HOCKEY", "TENNIS","GOLF"
results_fixtures_extraction(driver, ["FOOTBALL","BASKETBALL","BASEBALL", "AM._FOOTBALL"], name_section = 'fixtures')
# Out:
# ######################################################################################################
# #                                              FIXTURES                                              #
# ######################################################################################################
#
#
#
# ######################################################################################################
# #                                              FOOTBALL                                              #
# ######################################################################################################
#
# [SKIP] ARGENTINA_Liga Profesional — extract_fixtures.extract=false
# [SKIP] ARGENTINA_Copa de la Liga Profesional — extract_fixtures.extract=false
# [SKIP] BELGIUM_Jupiler Pro League — extract_fixtures.extract=false
# [SKIP] BOLIVIA_Division Profesional — extract_fixtures.extract=false
# [SKIP] BRAZIL_Serie A Betano — extract_fixtures.extract=false
# [SKIP] CHILE_Liga de Primera — extract_fixtures.extract=false
#
#
# #######################################################################################################
# #                    LEAGUE: CHINA_Super League, MATCH NUMBER: 0 TEAMS CREATED: 16                    #
# #######################################################################################################
#
# ['ROUND_22.json', 'ROUND_23.json', 'ROUND_25.json', 'ROUND_3.json', 'ROUND_4.json']
#
# Current file:  check_points/fixtures/CHINA_Super League/ROUND_22.json
#
#
# ######################################################################################################
# #                  NEW EVENT check_points/fixtures/CHINA_Super League/ROUND_22.json                  #
# ######################################################################################################
#
#
#
# #######################################################################################################
# #               https://www.flashscore.com/match/4I1TyK23/#/match-summary/match-summary               #
# #######################################################################################################
#
# WAITING DETAILS
# event_info part 1:  {'match_id': 'dbd5cf33-4396-47b6-aa77-382b0a146824', 'match_date': '07.08.2026 13:35', 'start_time': '', 'end_time': '', 'name': 'Beijing Guoan~Shenzhen Xinpengcheng', 'home': 'Beijing Guoan', 'visitor': 'Shenzhen Xinpengcheng', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/4I1TyK23/#/match-summary/match-summary', 'place': '', 'country_id': '20gcjyxb6mcrc8fuw', 'match_country': ''}
# Input date format:  07.08.2026 13:35
# event_info end:  {'match_id': 'dbd5cf33-4396-47b6-aa77-382b0a146824', 'match_date': datetime.date(2026, 8, 7), 'start_time': datetime.time(12, 35, 0, 17), 'end_time': datetime.time(12, 35, 0, 17), 'name': 'Beijing Guoan~Shenzhen Xinpengcheng', 'home': 'Beijing Guoan', 'visitor': 'Shenzhen Xinpengcheng', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/4I1TyK23/#/match-summary/match-summary', 'place': '', 'country_id': '20gcjyxb6mcrc8fuw', 'match_country': '', 'tournament_id': '', 'statistic': '{}', 'league_id': '849a5dd9-f003-4a4f-a530-f635df2267cc', 'season_id': '38cd0e11-c6da-436f-aafc-aabed92705d1', 'rounds': 'ROUND_22'}
# FIND TEAM IDs
# CREATE STADIUM
# Creating Stadium
#  CREATE NEW STADIUM
# CREATE MATCH
#
#
# #######################################################################################################
# #                                          NEW MATCH ADDED:                                           #
# #######################################################################################################
#
# dict_match:  {}
#
#
# ######################################################################################################
# #       SAVE CHECKPOINT IN ROUND FILE ROUND_22.json, match=Beijing Guoan~Shenzhen Xinpengcheng       #
# ######################################################################################################
#
# END MATCH FUNCTION
#
#
# ######################################################################################################
# #                  NEW EVENT check_points/fixtures/CHINA_Super League/ROUND_22.json                  #
# ######################################################################################################
#
#
#
# #######################################################################################################
# #               https://www.flashscore.com/match/xWayzbXF/#/match-summary/match-summary               #
# #######################################################################################################
#
# WAITING DETAILS
# event_info part 1:  {'match_id': '5e6eedb6-aa86-424b-9e03-dad345c66177', 'match_date': '08.08.2026 13:00', 'start_time': '', 'end_time': '', 'name': 'Qingdao Hainiu~Shanghai Shenhua', 'home': 'Qingdao Hainiu', 'visitor': 'Shanghai Shenhua', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/xWayzbXF/#/match-summary/match-summary', 'place': '', 'country_id': '20gcjyxb6mcrc8fuw', 'match_country': ''}
# Input date format:  08.08.2026 13:00
# event_info end:  {'match_id': '5e6eedb6-aa86-424b-9e03-dad345c66177', 'match_date': datetime.date(2026, 8, 8), 'start_time': datetime.time(12, 0, 0, 17), 'end_time': datetime.time(12, 0, 0, 17), 'name': 'Qingdao Hainiu~Shanghai Shenhua', 'home': 'Qingdao Hainiu', 'visitor': 'Shanghai Shenhua', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/xWayzbXF/#/match-summary/match-summary', 'place': '', 'country_id': '20gcjyxb6mcrc8fuw', 'match_country': '', 'tournament_id': '', 'statistic': '{}', 'league_id': '849a5dd9-f003-4a4f-a530-f635df2267cc', 'season_id': '38cd0e11-c6da-436f-aafc-aabed92705d1', 'rounds': 'ROUND_22'}
# FIND TEAM IDs
# CREATE STADIUM
# Creating Stadium
#  CREATE NEW STADIUM
# CREATE MATCH
#
#
# #######################################################################################################
# #                                          NEW MATCH ADDED:                                           #
# #######################################################################################################
#
# dict_match:  {}
#
#
# ######################################################################################################
# #         SAVE CHECKPOINT IN ROUND FILE ROUND_22.json, match=Qingdao Hainiu~Shanghai Shenhua         #
# ######################################################################################################
#
# END MATCH FUNCTION
#
#
# ######################################################################################################
# #                  NEW EVENT check_points/fixtures/CHINA_Super League/ROUND_22.json                  #
# ######################################################################################################
#
#
#
# #######################################################################################################
# #               https://www.flashscore.com/match/OnbqYy2S/#/match-summary/match-summary               #
# #######################################################################################################
#
# WAITING DETAILS
# event_info part 1:  {'match_id': '45caf614-dbe4-4d50-b4c0-a418db79a5cb', 'match_date': '08.08.2026 13:35', 'start_time': '', 'end_time': '', 'name': 'Dalian Yingbo~Liaoning Tieren', 'home': 'Dalian Yingbo', 'visitor': 'Liaoning Tieren', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/OnbqYy2S/#/match-summary/match-summary', 'place': '', 'country_id': '20gcjyxb6mcrc8fuw', 'match_country': ''}
# Input date format:  08.08.2026 13:35
# event_info end:  {'match_id': '45caf614-dbe4-4d50-b4c0-a418db79a5cb', 'match_date': datetime.date(2026, 8, 8), 'start_time': datetime.time(12, 35, 0, 17), 'end_time': datetime.time(12, 35, 0, 17), 'name': 'Dalian Yingbo~Liaoning Tieren', 'home': 'Dalian Yingbo', 'visitor': 'Liaoning Tieren', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/OnbqYy2S/#/match-summary/match-summary', 'place': '', 'country_id': '20gcjyxb6mcrc8fuw', 'match_country': '', 'tournament_id': '', 'statistic': '{}', 'league_id': '849a5dd9-f003-4a4f-a530-f635df2267cc', 'season_id': '38cd0e11-c6da-436f-aafc-aabed92705d1', 'rounds': 'ROUND_22'}
# FIND TEAM IDs
# ### TEAM NOT FOUND IN LIST OF FILES ######### 'Liaoning Tieren'
# [DB] team_id NOT FOUND: Dalian Yingbo in league 849a5dd9-f003-4a4f-a530-f635df2267cc
# [DB] team_id NOT FOUND: Liaoning Tieren in league 849a5dd9-f003-4a4f-a530-f635df2267cc
# CREATE STADIUM
# Creating Stadium
#  CREATE NEW STADIUM
# CREATE MATCH
#
#
# #######################################################################################################
# #                                          NEW MATCH ADDED:                                           #
# #######################################################################################################
#
# dict_match:  {}
#
#
# ######################################################################################################
# #          SAVE CHECKPOINT IN ROUND FILE ROUND_22.json, match=Dalian Yingbo~Liaoning Tieren          #
# ######################################################################################################
#
# END MATCH FUNCTION
#
#
# ######################################################################################################
# #                  NEW EVENT check_points/fixtures/CHINA_Super League/ROUND_22.json                  #
# ######################################################################################################
#
#
#
# #######################################################################################################
# #               https://www.flashscore.com/match/fVlFSFPk/#/match-summary/match-summary               #
# #######################################################################################################
#
# WAITING DETAILS
# event_info part 1:  {'match_id': 'b6e93aba-b284-4655-b05b-a3fe94cdaa24', 'match_date': '08.08.2026 13:35', 'start_time': '', 'end_time': '', 'name': 'Zhejiang Professional~Wuhan Three Towns', 'home': 'Zhejiang Professional', 'visitor': 'Wuhan Three Towns', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/fVlFSFPk/#/match-summary/match-summary', 'place': '', 'country_id': '20gcjyxb6mcrc8fuw', 'match_country': ''}
# Input date format:  08.08.2026 13:35
# event_info end:  {'match_id': 'b6e93aba-b284-4655-b05b-a3fe94cdaa24', 'match_date': datetime.date(2026, 8, 8), 'start_time': datetime.time(12, 35, 0, 17), 'end_time': datetime.time(12, 35, 0, 17), 'name': 'Zhejiang Professional~Wuhan Three Towns', 'home': 'Zhejiang Professional', 'visitor': 'Wuhan Three Towns', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/fVlFSFPk/#/match-summary/match-summary', 'place': '', 'country_id': '20gcjyxb6mcrc8fuw', 'match_country': '', 'tournament_id': '', 'statistic': '{}', 'league_id': '849a5dd9-f003-4a4f-a530-f635df2267cc', 'season_id': '38cd0e11-c6da-436f-aafc-aabed92705d1', 'rounds': 'ROUND_22'}
# FIND TEAM IDs
# CREATE STADIUM
# Creating Stadium
#  CREATE NEW STADIUM
# CREATE MATCH
#
#
# #######################################################################################################
# #                                          NEW MATCH ADDED:                                           #
# #######################################################################################################
#
# dict_match:  {}
#
#
# ######################################################################################################
# #     SAVE CHECKPOINT IN ROUND FILE ROUND_22.json, match=Zhejiang Professional~Wuhan Three Towns     #
# ######################################################################################################
#
# END MATCH FUNCTION
#
#
# ######################################################################################################
# #                  NEW EVENT check_points/fixtures/CHINA_Super League/ROUND_22.json                  #
# ######################################################################################################
#
#
#
# #######################################################################################################
# #               https://www.flashscore.com/match/SrmNQgf2/#/match-summary/match-summary               #
# #######################################################################################################
#
# WAITING DETAILS
# event_info part 1:  {'match_id': '6718f248-047d-4721-ad98-60e7a1a9db3f', 'match_date': '08.08.2026 14:00', 'start_time': '', 'end_time': '', 'name': 'Yunnan Yukun~Chengdu Rongcheng', 'home': 'Yunnan Yukun', 'visitor': 'Chengdu Rongcheng', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/SrmNQgf2/#/match-summary/match-summary', 'place': '', 'country_id': '20gcjyxb6mcrc8fuw', 'match_country': ''}
# Input date format:  08.08.2026 14:00
# event_info end:  {'match_id': '6718f248-047d-4721-ad98-60e7a1a9db3f', 'match_date': datetime.date(2026, 8, 8), 'start_time': datetime.time(13, 0, 0, 17), 'end_time': datetime.time(13, 0, 0, 17), 'name': 'Yunnan Yukun~Chengdu Rongcheng', 'home': 'Yunnan Yukun', 'visitor': 'Chengdu Rongcheng', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/SrmNQgf2/#/match-summary/match-summary', 'place': '', 'country_id': '20gcjyxb6mcrc8fuw', 'match_country': '', 'tournament_id': '', 'statistic': '{}', 'league_id': '849a5dd9-f003-4a4f-a530-f635df2267cc', 'season_id': '38cd0e11-c6da-436f-aafc-aabed92705d1', 'rounds': 'ROUND_22'}
# FIND TEAM IDs
# CREATE STADIUM
# Creating Stadium
#  CREATE NEW STADIUM
# CREATE MATCH
#
#
# #######################################################################################################
# #                                          NEW MATCH ADDED:                                           #
# #######################################################################################################
#
# dict_match:  {}
#
#
# #######################################################################################################
# #          SAVE CHECKPOINT IN ROUND FILE ROUND_22.json, match=Yunnan Yukun~Chengdu Rongcheng          #
# #######################################################################################################
#
# END MATCH FUNCTION
#
#
# ######################################################################################################
# #                  NEW EVENT check_points/fixtures/CHINA_Super League/ROUND_22.json                  #
# ######################################################################################################
#
#
#
# #######################################################################################################
# #               https://www.flashscore.com/match/fku9lcn9/#/match-summary/match-summary               #
# #######################################################################################################
#
# WAITING DETAILS
# event_info part 1:  {'match_id': '94d8eeb6-f23f-408e-8f18-6ba1d7042cc1', 'match_date': '09.08.2026 13:00', 'start_time': '', 'end_time': '', 'name': 'Henan Songshan Longmen~Qingdao West Coast', 'home': 'Henan Songshan Longmen', 'visitor': 'Qingdao West Coast', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/fku9lcn9/#/match-summary/match-summary', 'place': '', 'country_id': '20gcjyxb6mcrc8fuw', 'match_country': ''}
# Input date format:  09.08.2026 13:00
# event_info end:  {'match_id': '94d8eeb6-f23f-408e-8f18-6ba1d7042cc1', 'match_date': datetime.date(2026, 8, 9), 'start_time': datetime.time(12, 0, 0, 17), 'end_time': datetime.time(12, 0, 0, 17), 'name': 'Henan Songshan Longmen~Qingdao West Coast', 'home': 'Henan Songshan Longmen', 'visitor': 'Qingdao West Coast', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/fku9lcn9/#/match-summary/match-summary', 'place': '', 'country_id': '20gcjyxb6mcrc8fuw', 'match_country': '', 'tournament_id': '', 'statistic': '{}', 'league_id': '849a5dd9-f003-4a4f-a530-f635df2267cc', 'season_id': '38cd0e11-c6da-436f-aafc-aabed92705d1', 'rounds': 'ROUND_22'}
# FIND TEAM IDs
# CREATE STADIUM
# Creating Stadium
#  CREATE NEW STADIUM
# CREATE MATCH
#
#
# #######################################################################################################
# #                                          NEW MATCH ADDED:                                           #
# #######################################################################################################
#
# dict_match:  {}
# ######################################################################################################
# #    SAVE CHECKPOINT IN ROUND FILE ROUND_22.json, match=Henan Songshan Longmen~Qingdao West Coast    #
# ######################################################################################################
#
# END MATCH FUNCTION
#
#
# ######################################################################################################
# #                  NEW EVENT check_points/fixtures/CHINA_Super League/ROUND_22.json                  #
# ######################################################################################################
#
#
#
# #######################################################################################################
# #               https://www.flashscore.com/match/0nrHnyHL/#/match-summary/match-summary               #
# #######################################################################################################
#
# WAITING DETAILS
# event_info part 1:  {'match_id': '503d5830-39ac-4253-aaac-b3e090264ff2', 'match_date': '09.08.2026 13:35', 'start_time': '', 'end_time': '', 'name': 'Chongqing Tonglianglong~Shanghai Port', 'home': 'Chongqing Tonglianglong', 'visitor': 'Shanghai Port', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/0nrHnyHL/#/match-summary/match-summary', 'place': '', 'country_id': '20gcjyxb6mcrc8fuw', 'match_country': ''}
# Input date format:  09.08.2026 13:35
# event_info end:  {'match_id': '503d5830-39ac-4253-aaac-b3e090264ff2', 'match_date': datetime.date(2026, 8, 9), 'start_time': datetime.time(12, 35, 0, 17), 'end_time': datetime.time(12, 35, 0, 17), 'name': 'Chongqing Tonglianglong~Shanghai Port', 'home': 'Chongqing Tonglianglong', 'visitor': 'Shanghai Port', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/0nrHnyHL/#/match-summary/match-summary', 'place': '', 'country_id': '20gcjyxb6mcrc8fuw', 'match_country': '', 'tournament_id': '', 'statistic': '{}', 'league_id': '849a5dd9-f003-4a4f-a530-f635df2267cc', 'season_id': '38cd0e11-c6da-436f-aafc-aabed92705d1', 'rounds': 'ROUND_22'}
# FIND TEAM IDs
# ### TEAM NOT FOUND IN LIST OF FILES ######### 'Chongqing Tonglianglong'
# [DB] team_id NOT FOUND: Chongqing Tonglianglong in league 849a5dd9-f003-4a4f-a530-f635df2267cc
# [DB] team_id NOT FOUND: Shanghai Port in league 849a5dd9-f003-4a4f-a530-f635df2267cc
# CREATE STADIUM
# Creating Stadium
#  CREATE NEW STADIUM
# CREATE MATCH
#
#
# #######################################################################################################
# #                                          NEW MATCH ADDED:                                           #
# #######################################################################################################
#
# dict_match:  {}
#
#
# ######################################################################################################
# #      SAVE CHECKPOINT IN ROUND FILE ROUND_22.json, match=Chongqing Tonglianglong~Shanghai Port      #
# ######################################################################################################
#
# END MATCH FUNCTION
#
#
# ######################################################################################################
# #                  NEW EVENT check_points/fixtures/CHINA_Super League/ROUND_22.json                  #
# ######################################################################################################
#
#
#
# #######################################################################################################
# #               https://www.flashscore.com/match/dITnsFvq/#/match-summary/match-summary               #
# #######################################################################################################
#
# WAITING DETAILS
# event_info part 1:  {'match_id': '837a5d7a-796b-4556-a220-42edcd934236', 'match_date': '09.08.2026 14:00', 'start_time': '', 'end_time': '', 'name': 'Shandong Taishan~Tianjin Jinmen Tiger', 'home': 'Shandong Taishan', 'visitor': 'Tianjin Jinmen Tiger', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/dITnsFvq/#/match-summary/match-summary', 'place': '', 'country_id': '20gcjyxb6mcrc8fuw', 'match_country': ''}
# Input date format:  09.08.2026 14:00
# event_info end:  {'match_id': '837a5d7a-796b-4556-a220-42edcd934236', 'match_date': datetime.date(2026, 8, 9), 'start_time': datetime.time(13, 0, 0, 17), 'end_time': datetime.time(13, 0, 0, 17), 'name': 'Shandong Taishan~Tianjin Jinmen Tiger', 'home': 'Shandong Taishan', 'visitor': 'Tianjin Jinmen Tiger', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/dITnsFvq/#/match-summary/match-summary', 'place': '', 'country_id': '20gcjyxb6mcrc8fuw', 'match_country': '', 'tournament_id': '', 'statistic': '{}', 'league_id': '849a5dd9-f003-4a4f-a530-f635df2267cc', 'season_id': '38cd0e11-c6da-436f-aafc-aabed92705d1', 'rounds': 'ROUND_22'}
# FIND TEAM IDs
# CREATE STADIUM
# Creating Stadium
#  CREATE NEW STADIUM
# CREATE MATCH
#
#
# #######################################################################################################
# #                                          NEW MATCH ADDED:                                           #
# #######################################################################################################
#
# dict_match:  {}
#
#
# ######################################################################################################
# #      SAVE CHECKPOINT IN ROUND FILE ROUND_22.json, match=Shandong Taishan~Tianjin Jinmen Tiger      #
# ######################################################################################################
#
# END MATCH FUNCTION
# Current file:  check_points/fixtures/CHINA_Super League/ROUND_23.json
#
#
# ######################################################################################################
# #                  NEW EVENT check_points/fixtures/CHINA_Super League/ROUND_23.json                  #
# ######################################################################################################
#
#
#
# #######################################################################################################
# #               https://www.flashscore.com/match/4rXfug9e/#/match-summary/match-summary               #
# #######################################################################################################
#
# WAITING DETAILS
# event_info part 1:  {'match_id': 'd2621184-0b9f-4be2-a8d2-26a63d1ac080', 'match_date': '14.08.2026 13:35', 'start_time': '', 'end_time': '', 'name': 'Shandong Taishan~Qingdao Hainiu', 'home': 'Shandong Taishan', 'visitor': 'Qingdao Hainiu', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/4rXfug9e/#/match-summary/match-summary', 'place': '', 'country_id': '20gcjyxb6mcrc8fuw', 'match_country': ''}
# Input date format:  14.08.2026 13:35
# event_info end:  {'match_id': 'd2621184-0b9f-4be2-a8d2-26a63d1ac080', 'match_date': datetime.date(2026, 8, 14), 'start_time': datetime.time(12, 35, 0, 17), 'end_time': datetime.time(12, 35, 0, 17), 'name': 'Shandong Taishan~Qingdao Hainiu', 'home': 'Shandong Taishan', 'visitor': 'Qingdao Hainiu', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/4rXfug9e/#/match-summary/match-summary', 'place': '', 'country_id': '20gcjyxb6mcrc8fuw', 'match_country': '', 'tournament_id': '', 'statistic': '{}', 'league_id': '849a5dd9-f003-4a4f-a530-f635df2267cc', 'season_id': '38cd0e11-c6da-436f-aafc-aabed92705d1', 'rounds': 'ROUND_23'}
# FIND TEAM IDs
# CREATE STADIUM
# Creating Stadium
#  STADIUM READY, with id: c32ed895-d48e-4c1a-beba-e6b753817621
# CREATE MATCH
#
#
# #######################################################################################################
# #                                          NEW MATCH ADDED:                                           #
# #######################################################################################################
#
# dict_match:  {}
#
#
# ######################################################################################################
# #         SAVE CHECKPOINT IN ROUND FILE ROUND_23.json, match=Shandong Taishan~Qingdao Hainiu         #
# ######################################################################################################
#
# END MATCH FUNCTION
#
#
# ######################################################################################################
# #                  NEW EVENT check_points/fixtures/CHINA_Super League/ROUND_23.json                  #
# ######################################################################################################
#
#
#
# #######################################################################################################
# #               https://www.flashscore.com/match/C8z3wXw8/#/match-summary/match-summary               #
# #######################################################################################################
#
# WAITING DETAILS
# event_info part 1:  {'match_id': 'cc5760a8-bb9a-46eb-ab49-ce5e3f3ba3db', 'match_date': '14.08.2026 13:35', 'start_time': '', 'end_time': '', 'name': 'Wuhan Three Towns~Shanghai Port', 'home': 'Wuhan Three Towns', 'visitor': 'Shanghai Port', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/C8z3wXw8/#/match-summary/match-summary', 'place': '', 'country_id': '20gcjyxb6mcrc8fuw', 'match_country': ''}
# Input date format:  14.08.2026 13:35
# event_info end:  {'match_id': 'cc5760a8-bb9a-46eb-ab49-ce5e3f3ba3db', 'match_date': datetime.date(2026, 8, 14), 'start_time': datetime.time(12, 35, 0, 17), 'end_time': datetime.time(12, 35, 0, 17), 'name': 'Wuhan Three Towns~Shanghai Port', 'home': 'Wuhan Three Towns', 'visitor': 'Shanghai Port', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/C8z3wXw8/#/match-summary/match-summary', 'place': '', 'country_id': '20gcjyxb6mcrc8fuw', 'match_country': '', 'tournament_id': '', 'statistic': '{}', 'league_id': '849a5dd9-f003-4a4f-a530-f635df2267cc', 'season_id': '38cd0e11-c6da-436f-aafc-aabed92705d1', 'rounds': 'ROUND_23'}
# FIND TEAM IDs
# CREATE STADIUM
# Creating Stadium
#  CREATE NEW STADIUM
# CREATE MATCH
#
#
# #######################################################################################################
# #                                          NEW MATCH ADDED:                                           #
# #######################################################################################################
#
# dict_match:  {}
#
#
# ######################################################################################################
# #         SAVE CHECKPOINT IN ROUND FILE ROUND_23.json, match=Wuhan Three Towns~Shanghai Port         #
# ######################################################################################################
#
# END MATCH FUNCTION
#
#
# ######################################################################################################
# #                  NEW EVENT check_points/fixtures/CHINA_Super League/ROUND_23.json                  #
# ######################################################################################################
#
#
#
# #######################################################################################################
# #               https://www.flashscore.com/match/6V9noqcE/#/match-summary/match-summary               #
# #######################################################################################################
#
# WAITING DETAILS
# event_info part 1:  {'match_id': '588f0bd3-bf71-4cf8-83ab-b178351ce5fc', 'match_date': '14.08.2026 14:00', 'start_time': '', 'end_time': '', 'name': 'Qingdao West Coast~Chongqing Tonglianglong', 'home': 'Qingdao West Coast', 'visitor': 'Chongqing Tonglianglong', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/6V9noqcE/#/match-summary/match-summary', 'place': '', 'country_id': '20gcjyxb6mcrc8fuw', 'match_country': ''}
# Input date format:  14.08.2026 14:00
# event_info end:  {'match_id': '588f0bd3-bf71-4cf8-83ab-b178351ce5fc', 'match_date': datetime.date(2026, 8, 14), 'start_time': datetime.time(13, 0, 0, 17), 'end_time': datetime.time(13, 0, 0, 17), 'name': 'Qingdao West Coast~Chongqing Tonglianglong', 'home': 'Qingdao West Coast', 'visitor': 'Chongqing Tonglianglong', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/6V9noqcE/#/match-summary/match-summary', 'place': '', 'country_id': '20gcjyxb6mcrc8fuw', 'match_country': '', 'tournament_id': '', 'statistic': '{}', 'league_id': '849a5dd9-f003-4a4f-a530-f635df2267cc', 'season_id': '38cd0e11-c6da-436f-aafc-aabed92705d1', 'rounds': 'ROUND_23'}
# FIND TEAM IDs
# CREATE STADIUM
# Creating Stadium
#  CREATE NEW STADIUM
# CREATE MATCH
#
#
# #######################################################################################################
# #                                          NEW MATCH ADDED:                                           #
# #######################################################################################################
#
# dict_match:  {}
#
#
# #######################################################################################################
# #    SAVE CHECKPOINT IN ROUND FILE ROUND_23.json, match=Qingdao West Coast~Chongqing Tonglianglong    #
# #######################################################################################################
#
# END MATCH FUNCTION
#
#
# ######################################################################################################
# #                  NEW EVENT check_points/fixtures/CHINA_Super League/ROUND_23.json                  #
# ######################################################################################################
#
#
#
# #######################################################################################################
# #               https://www.flashscore.com/match/xWoJSzsm/#/match-summary/match-summary               #
# #######################################################################################################
#
# WAITING DETAILS
# event_info part 1:  {'match_id': '52ffa9a8-f82d-460a-90f7-2031123ac34c', 'match_date': '15.08.2026 13:00', 'start_time': '', 'end_time': '', 'name': 'Liaoning Tieren~Shenzhen Xinpengcheng', 'home': 'Liaoning Tieren', 'visitor': 'Shenzhen Xinpengcheng', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/xWoJSzsm/#/match-summary/match-summary', 'place': '', 'country_id': '20gcjyxb6mcrc8fuw', 'match_country': ''}
# Input date format:  15.08.2026 13:00
# event_info end:  {'match_id': '52ffa9a8-f82d-460a-90f7-2031123ac34c', 'match_date': datetime.date(2026, 8, 15), 'start_time': datetime.time(12, 0, 0, 17), 'end_time': datetime.time(12, 0, 0, 17), 'name': 'Liaoning Tieren~Shenzhen Xinpengcheng', 'home': 'Liaoning Tieren', 'visitor': 'Shenzhen Xinpengcheng', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/xWoJSzsm/#/match-summary/match-summary', 'place': '', 'country_id': '20gcjyxb6mcrc8fuw', 'match_country': '', 'tournament_id': '', 'statistic': '{}', 'league_id': '849a5dd9-f003-4a4f-a530-f635df2267cc', 'season_id': '38cd0e11-c6da-436f-aafc-aabed92705d1', 'rounds': 'ROUND_23'}
# FIND TEAM IDs
# ### TEAM NOT FOUND IN LIST OF FILES ######### 'Liaoning Tieren'
# [DB] team_id NOT FOUND: Liaoning Tieren in league 849a5dd9-f003-4a4f-a530-f635df2267cc
# [DB] team_id NOT FOUND: Shenzhen Xinpengcheng in league 849a5dd9-f003-4a4f-a530-f635df2267cc
# CREATE STADIUM
# Creating Stadium
#  CREATE NEW STADIUM
# CREATE MATCH
#
#
# #######################################################################################################
# #                                          NEW MATCH ADDED:                                           #
# #######################################################################################################
#
# dict_match:  {}
#
#
# ######################################################################################################
# #      SAVE CHECKPOINT IN ROUND FILE ROUND_23.json, match=Liaoning Tieren~Shenzhen Xinpengcheng      #
# ######################################################################################################
#
# END MATCH FUNCTION
#
#
# ######################################################################################################
# #                  NEW EVENT check_points/fixtures/CHINA_Super League/ROUND_23.json                  #
# ######################################################################################################
#
#
#
# #######################################################################################################
# #               https://www.flashscore.com/match/I9mZOhtC/#/match-summary/match-summary               #
# #######################################################################################################
#
# WAITING DETAILS
# event_info part 1:  {'match_id': '3bf8b6d7-9142-4bb8-8dc9-b374084c214a', 'match_date': '15.08.2026 13:35', 'start_time': '', 'end_time': '', 'name': 'Tianjin Jinmen Tiger~Beijing Guoan', 'home': 'Tianjin Jinmen Tiger', 'visitor': 'Beijing Guoan', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/I9mZOhtC/#/match-summary/match-summary', 'place': '', 'country_id': '20gcjyxb6mcrc8fuw', 'match_country': ''}
# Input date format:  15.08.2026 13:35
# event_info end:  {'match_id': '3bf8b6d7-9142-4bb8-8dc9-b374084c214a', 'match_date': datetime.date(2026, 8, 15), 'start_time': datetime.time(12, 35, 0, 17), 'end_time': datetime.time(12, 35, 0, 17), 'name': 'Tianjin Jinmen Tiger~Beijing Guoan', 'home': 'Tianjin Jinmen Tiger', 'visitor': 'Beijing Guoan', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/I9mZOhtC/#/match-summary/match-summary', 'place': '', 'country_id': '20gcjyxb6mcrc8fuw', 'match_country': '', 'tournament_id': '', 'statistic': '{}', 'league_id': '849a5dd9-f003-4a4f-a530-f635df2267cc', 'season_id': '38cd0e11-c6da-436f-aafc-aabed92705d1', 'rounds': 'ROUND_23'}
# FIND TEAM IDs
# CREATE STADIUM
# Creating Stadium
#  CREATE NEW STADIUM
# CREATE MATCH
#
#
# #######################################################################################################
# #                                          NEW MATCH ADDED:                                           #
# #######################################################################################################
#
# dict_match:  {}
#
#
# #######################################################################################################
# #        SAVE CHECKPOINT IN ROUND FILE ROUND_23.json, match=Tianjin Jinmen Tiger~Beijing Guoan        #
# #######################################################################################################
#
# END MATCH FUNCTION
#
#
# ######################################################################################################
# #                  NEW EVENT check_points/fixtures/CHINA_Super League/ROUND_23.json                  #
# ######################################################################################################
#
#
#
# #######################################################################################################
# #               https://www.flashscore.com/match/pdkRQEBa/#/match-summary/match-summary               #
# #######################################################################################################
#
# WAITING DETAILS
# event_info part 1:  {'match_id': '367c1bc3-f047-4dc2-b11e-23f00dfb5a99', 'match_date': '15.08.2026 13:35', 'start_time': '', 'end_time': '', 'name': 'Zhejiang Professional~Chengdu Rongcheng', 'home': 'Zhejiang Professional', 'visitor': 'Chengdu Rongcheng', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/pdkRQEBa/#/match-summary/match-summary', 'place': '', 'country_id': '20gcjyxb6mcrc8fuw', 'match_country': ''}
# Input date format:  15.08.2026 13:35
# event_info end:  {'match_id': '367c1bc3-f047-4dc2-b11e-23f00dfb5a99', 'match_date': datetime.date(2026, 8, 15), 'start_time': datetime.time(12, 35, 0, 17), 'end_time': datetime.time(12, 35, 0, 17), 'name': 'Zhejiang Professional~Chengdu Rongcheng', 'home': 'Zhejiang Professional', 'visitor': 'Chengdu Rongcheng', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/pdkRQEBa/#/match-summary/match-summary', 'place': '', 'country_id': '20gcjyxb6mcrc8fuw', 'match_country': '', 'tournament_id': '', 'statistic': '{}', 'league_id': '849a5dd9-f003-4a4f-a530-f635df2267cc', 'season_id': '38cd0e11-c6da-436f-aafc-aabed92705d1', 'rounds': 'ROUND_23'}
# FIND TEAM IDs
# CREATE STADIUM
# Creating Stadium
#  STADIUM READY, with id: e31f1bf3-3cd8-4389-8d17-7c30647843f2
# CREATE MATCH
#
#
# #######################################################################################################
# #                                          NEW MATCH ADDED:                                           #
# #######################################################################################################
#
# dict_match:  {}
#
#
# ######################################################################################################
# #     SAVE CHECKPOINT IN ROUND FILE ROUND_23.json, match=Zhejiang Professional~Chengdu Rongcheng     #
# ######################################################################################################
#
# END MATCH FUNCTION
#
#
# ######################################################################################################
# #                  NEW EVENT check_points/fixtures/CHINA_Super League/ROUND_23.json                  #
# ######################################################################################################
#
#
#
# #######################################################################################################
# #               https://www.flashscore.com/match/QZjsNWAO/#/match-summary/match-summary               #
# #######################################################################################################
#
# WAITING DETAILS
# event_info part 1:  {'match_id': '15ebcfac-504f-48ca-9a05-bc2f9fbacef1', 'match_date': '15.08.2026 14:00', 'start_time': '', 'end_time': '', 'name': 'Shanghai Shenhua~Henan Songshan Longmen', 'home': 'Shanghai Shenhua', 'visitor': 'Henan Songshan Longmen', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/QZjsNWAO/#/match-summary/match-summary', 'place': '', 'country_id': '20gcjyxb6mcrc8fuw', 'match_country': ''}
# Input date format:  15.08.2026 14:00
# event_info end:  {'match_id': '15ebcfac-504f-48ca-9a05-bc2f9fbacef1', 'match_date': datetime.date(2026, 8, 15), 'start_time': datetime.time(13, 0, 0, 17), 'end_time': datetime.time(13, 0, 0, 17), 'name': 'Shanghai Shenhua~Henan Songshan Longmen', 'home': 'Shanghai Shenhua', 'visitor': 'Henan Songshan Longmen', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/QZjsNWAO/#/match-summary/match-summary', 'place': '', 'country_id': '20gcjyxb6mcrc8fuw', 'match_country': '', 'tournament_id': '', 'statistic': '{}', 'league_id': '849a5dd9-f003-4a4f-a530-f635df2267cc', 'season_id': '38cd0e11-c6da-436f-aafc-aabed92705d1', 'rounds': 'ROUND_23'}
# FIND TEAM IDs
# CREATE STADIUM
# Creating Stadium
#  CREATE NEW STADIUM
# CREATE MATCH
#
#
# #######################################################################################################
# #                                          NEW MATCH ADDED:                                           #
# #######################################################################################################
#
# dict_match:  {}
#
#
# ######################################################################################################
# #     SAVE CHECKPOINT IN ROUND FILE ROUND_23.json, match=Shanghai Shenhua~Henan Songshan Longmen     #
# ######################################################################################################
#
# END MATCH FUNCTION
#
#
# ######################################################################################################
# #                  NEW EVENT check_points/fixtures/CHINA_Super League/ROUND_23.json                  #
# ######################################################################################################
#
#
#
# #######################################################################################################
# #               https://www.flashscore.com/match/EVVjszdt/#/match-summary/match-summary               #
# #######################################################################################################
#
# WAITING DETAILS
# event_info part 1:  {'match_id': 'adeea3f3-68aa-491d-b42d-585aca471d2d', 'match_date': '15.08.2026 14:00', 'start_time': '', 'end_time': '', 'name': 'Yunnan Yukun~Dalian Yingbo', 'home': 'Yunnan Yukun', 'visitor': 'Dalian Yingbo', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/EVVjszdt/#/match-summary/match-summary', 'place': '', 'country_id': '20gcjyxb6mcrc8fuw', 'match_country': ''}
# Input date format:  15.08.2026 14:00
# event_info end:  {'match_id': 'adeea3f3-68aa-491d-b42d-585aca471d2d', 'match_date': datetime.date(2026, 8, 15), 'start_time': datetime.time(13, 0, 0, 17), 'end_time': datetime.time(13, 0, 0, 17), 'name': 'Yunnan Yukun~Dalian Yingbo', 'home': 'Yunnan Yukun', 'visitor': 'Dalian Yingbo', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/EVVjszdt/#/match-summary/match-summary', 'place': '', 'country_id': '20gcjyxb6mcrc8fuw', 'match_country': '', 'tournament_id': '', 'statistic': '{}', 'league_id': '849a5dd9-f003-4a4f-a530-f635df2267cc', 'season_id': '38cd0e11-c6da-436f-aafc-aabed92705d1', 'rounds': 'ROUND_23'}
# FIND TEAM IDs
# CREATE STADIUM
# Creating Stadium
#  STADIUM READY, with id: 5099e52b-2475-4670-a9c4-e8f9673c77ef
# CREATE MATCH
#
#
# #######################################################################################################
# #                                          NEW MATCH ADDED:                                           #
# #######################################################################################################
#
# dict_match:  {}
#
#
# #######################################################################################################
# #            SAVE CHECKPOINT IN ROUND FILE ROUND_23.json, match=Yunnan Yukun~Dalian Yingbo            #
# #######################################################################################################
#
# END MATCH FUNCTION
# Current file:  check_points/fixtures/CHINA_Super League/ROUND_25.json
#
#
# ######################################################################################################
# #                  NEW EVENT check_points/fixtures/CHINA_Super League/ROUND_25.json                  #
# ######################################################################################################
#
#
#
# #######################################################################################################
# #               https://www.flashscore.com/match/8WJPrmXp/#/match-summary/match-summary               #
# #######################################################################################################
#
# WAITING DETAILS
# event_info part 1:  {'match_id': '215f340e-07e1-41bc-976e-64dc3b2a1edc', 'match_date': '28.08.2026 13:35', 'start_time': '', 'end_time': '', 'name': 'Dalian Yingbo~Beijing Guoan', 'home': 'Dalian Yingbo', 'visitor': 'Beijing Guoan', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/8WJPrmXp/#/match-summary/match-summary', 'place': '', 'country_id': '20gcjyxb6mcrc8fuw', 'match_country': ''}
# Input date format:  28.08.2026 13:35
# event_info end:  {'match_id': '215f340e-07e1-41bc-976e-64dc3b2a1edc', 'match_date': datetime.date(2026, 8, 28), 'start_time': datetime.time(12, 35, 0, 17), 'end_time': datetime.time(12, 35, 0, 17), 'name': 'Dalian Yingbo~Beijing Guoan', 'home': 'Dalian Yingbo', 'visitor': 'Beijing Guoan', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/8WJPrmXp/#/match-summary/match-summary', 'place': '', 'country_id': '20gcjyxb6mcrc8fuw', 'match_country': '', 'tournament_id': '', 'statistic': '{}', 'league_id': '849a5dd9-f003-4a4f-a530-f635df2267cc', 'season_id': '38cd0e11-c6da-436f-aafc-aabed92705d1', 'rounds': 'ROUND_25'}
# FIND TEAM IDs
# CREATE STADIUM
# Creating Stadium
#  STADIUM READY, with id: c1b1a22b-893c-4b93-a686-1da29107f40f
# CREATE MATCH
#
#
# #######################################################################################################
# #                                          NEW MATCH ADDED:                                           #
# #######################################################################################################
#
# dict_match:  {}
#
#
# ######################################################################################################
# #           SAVE CHECKPOINT IN ROUND FILE ROUND_25.json, match=Dalian Yingbo~Beijing Guoan           #
# ######################################################################################################
#
# END MATCH FUNCTION
#
#
# ######################################################################################################
# #                  NEW EVENT check_points/fixtures/CHINA_Super League/ROUND_25.json                  #
# ######################################################################################################
#
#
#
# #######################################################################################################
# #               https://www.flashscore.com/match/0Q6B6jPi/#/match-summary/match-summary               #
# #######################################################################################################
#
# WAITING DETAILS
# event_info part 1:  {'match_id': '77af02be-c8a3-4925-b033-f794e4771c0b', 'match_date': '28.08.2026 14:00', 'start_time': '', 'end_time': '', 'name': 'Shenzhen Xinpengcheng~Shanghai Port', 'home': 'Shenzhen Xinpengcheng', 'visitor': 'Shanghai Port', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/0Q6B6jPi/#/match-summary/match-summary', 'place': '', 'country_id': '20gcjyxb6mcrc8fuw', 'match_country': ''}
# Input date format:  28.08.2026 14:00
# event_info end:  {'match_id': '77af02be-c8a3-4925-b033-f794e4771c0b', 'match_date': datetime.date(2026, 8, 28), 'start_time': datetime.time(13, 0, 0, 17), 'end_time': datetime.time(13, 0, 0, 17), 'name': 'Shenzhen Xinpengcheng~Shanghai Port', 'home': 'Shenzhen Xinpengcheng', 'visitor': 'Shanghai Port', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/0Q6B6jPi/#/match-summary/match-summary', 'place': '', 'country_id': '20gcjyxb6mcrc8fuw', 'match_country': '', 'tournament_id': '', 'statistic': '{}', 'league_id': '849a5dd9-f003-4a4f-a530-f635df2267cc', 'season_id': '38cd0e11-c6da-436f-aafc-aabed92705d1', 'rounds': 'ROUND_25'}
# FIND TEAM IDs
# CREATE STADIUM
# Creating Stadium
#  CREATE NEW STADIUM
# CREATE MATCH
#
#
# #######################################################################################################
# #                                          NEW MATCH ADDED:                                           #
# ...
# FIND TEAM IDs
# ### TEAM NOT FOUND IN LIST OF FILES ######### 'Aucas'
# [DB] team_id NOT FOUND: Aucas in league 2a60c337-6d3c-418a-94d3-e351b990ce65
# [DB] team_id NOT FOUND: Delfin in league 2a60c337-6d3c-418a-94d3-e351b990ce65
# CREATE STADIUM
# Creating Stadium
#  CREATE NEW STADIUM
# CREATE MATCH
#
#
# #######################################################################################################
# #                                          NEW MATCH ADDED:                                           #
# #######################################################################################################
#
# dict_match:  {}
#
#
# #######################################################################################################
# #                   SAVE CHECKPOINT IN ROUND FILE ROUND_11.json, match=Aucas~Delfin                   #
# #######################################################################################################
#
# END MATCH FUNCTION
#
#
# ######################################################################################################
# #                   NEW EVENT check_points/fixtures/ECUADOR_Liga Pro/ROUND_11.json                   #
# ######################################################################################################
#
#
#
# #######################################################################################################
# #               https://www.flashscore.com/match/j7snKi6c/#/match-summary/match-summary               #
# #######################################################################################################
#
# WAITING DETAILS
# event_info part 1:  {'match_id': '201e1446-0747-4d80-b343-22cb118e089f', 'match_date': '26.04.2026 22:00', 'start_time': '', 'end_time': '', 'name': 'Emelec~LDU Quito', 'home': 'Emelec', 'visitor': 'LDU Quito', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/j7snKi6c/#/match-summary/match-summary', 'place': '', 'country_id': '63n7pzhku1bame5gj', 'match_country': ''}
# Input date format:  26.04.2026 22:00
# event_info end:  {'match_id': '201e1446-0747-4d80-b343-22cb118e089f', 'match_date': datetime.date(2026, 4, 26), 'start_time': datetime.time(21, 0, 0, 17), 'end_time': datetime.time(21, 0, 0, 17), 'name': 'Emelec~LDU Quito', 'home': 'Emelec', 'visitor': 'LDU Quito', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/j7snKi6c/#/match-summary/match-summary', 'place': '', 'country_id': '63n7pzhku1bame5gj', 'match_country': '', 'tournament_id': '', 'statistic': '{}', 'league_id': '2a60c337-6d3c-418a-94d3-e351b990ce65', 'season_id': '78102a43-27f5-492a-af68-f7adccd61658', 'rounds': 'ROUND_11'}
# FIND TEAM IDs
# ### TEAM NOT FOUND IN LIST OF FILES ######### 'Emelec'
# [DB] team_id NOT FOUND: Emelec in league 2a60c337-6d3c-418a-94d3-e351b990ce65
# [DB] team_id NOT FOUND: LDU Quito in league 2a60c337-6d3c-418a-94d3-e351b990ce65
# CREATE STADIUM
# Creating Stadium
#  CREATE NEW STADIUM
# CREATE MATCH
#
#
# #######################################################################################################
# #                                          NEW MATCH ADDED:                                           #
# #######################################################################################################
#
# dict_match:  {}
#
#
# #######################################################################################################
# #                 SAVE CHECKPOINT IN ROUND FILE ROUND_11.json, match=Emelec~LDU Quito                 #
# #######################################################################################################
#
# END MATCH FUNCTION
#
#
# ######################################################################################################
# #                   NEW EVENT check_points/fixtures/ECUADOR_Liga Pro/ROUND_11.json                   #
# ######################################################################################################
#
#
#
# #######################################################################################################
# #               https://www.flashscore.com/match/K40M3WLG/#/match-summary/match-summary               #
# #######################################################################################################
#
# WAITING DETAILS
# event_info part 1:  {'match_id': '39461d59-039c-4f5b-be13-4f1059c94f4b', 'match_date': '26.04.2026 22:00', 'start_time': '', 'end_time': '', 'name': 'Guayaquil City~Tecnico U.', 'home': 'Guayaquil City', 'visitor': 'Tecnico U.', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/K40M3WLG/#/match-summary/match-summary', 'place': '', 'country_id': '63n7pzhku1bame5gj', 'match_country': ''}
# Input date format:  26.04.2026 22:00
# event_info end:  {'match_id': '39461d59-039c-4f5b-be13-4f1059c94f4b', 'match_date': datetime.date(2026, 4, 26), 'start_time': datetime.time(21, 0, 0, 17), 'end_time': datetime.time(21, 0, 0, 17), 'name': 'Guayaquil City~Tecnico U.', 'home': 'Guayaquil City', 'visitor': 'Tecnico U.', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/K40M3WLG/#/match-summary/match-summary', 'place': '', 'country_id': '63n7pzhku1bame5gj', 'match_country': '', 'tournament_id': '', 'statistic': '{}', 'league_id': '2a60c337-6d3c-418a-94d3-e351b990ce65', 'season_id': '78102a43-27f5-492a-af68-f7adccd61658', 'rounds': 'ROUND_11'}
# FIND TEAM IDs
# ### TEAM NOT FOUND IN LIST OF FILES ######### 'Guayaquil City'
# [DB] team_id NOT FOUND: Guayaquil City in league 2a60c337-6d3c-418a-94d3-e351b990ce65
# [DB] team_id NOT FOUND: Tecnico U. in league 2a60c337-6d3c-418a-94d3-e351b990ce65
# CREATE STADIUM
# Creating Stadium
#  CREATE NEW STADIUM
# CREATE MATCH
#
#
# #######################################################################################################
# #                                          NEW MATCH ADDED:                                           #
# #######################################################################################################
#
# dict_match:  {}
#
#
# ######################################################################################################
# #            SAVE CHECKPOINT IN ROUND FILE ROUND_11.json, match=Guayaquil City~Tecnico U.            #
# ######################################################################################################
#
# END MATCH FUNCTION
#
#
# ######################################################################################################
# #                   NEW EVENT check_points/fixtures/ECUADOR_Liga Pro/ROUND_11.json                   #
# ######################################################################################################
#
#
#
# #######################################################################################################
# #               https://www.flashscore.com/match/IHLlkX6N/#/match-summary/match-summary               #
# #######################################################################################################
#
# WAITING DETAILS
# event_info part 1:  {'match_id': '4c481527-6fc7-429e-be8a-896913115175', 'match_date': '26.04.2026 22:00', 'start_time': '', 'end_time': '', 'name': 'Ind. del Valle~Leones del Norte', 'home': 'Ind. del Valle', 'visitor': 'Leones del Norte', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/IHLlkX6N/#/match-summary/match-summary', 'place': '', 'country_id': '63n7pzhku1bame5gj', 'match_country': ''}
# Input date format:  26.04.2026 22:00
# event_info end:  {'match_id': '4c481527-6fc7-429e-be8a-896913115175', 'match_date': datetime.date(2026, 4, 26), 'start_time': datetime.time(21, 0, 0, 17), 'end_time': datetime.time(21, 0, 0, 17), 'name': 'Ind. del Valle~Leones del Norte', 'home': 'Ind. del Valle', 'visitor': 'Leones del Norte', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/IHLlkX6N/#/match-summary/match-summary', 'place': '', 'country_id': '63n7pzhku1bame5gj', 'match_country': '', 'tournament_id': '', 'statistic': '{}', 'league_id': '2a60c337-6d3c-418a-94d3-e351b990ce65', 'season_id': '78102a43-27f5-492a-af68-f7adccd61658', 'rounds': 'ROUND_11'}
# FIND TEAM IDs
# ### TEAM NOT FOUND IN LIST OF FILES ######### 'Ind. del Valle'
# [DB] team_id NOT FOUND: Ind. del Valle in league 2a60c337-6d3c-418a-94d3-e351b990ce65
# [DB] team_id NOT FOUND: Leones del Norte in league 2a60c337-6d3c-418a-94d3-e351b990ce65
# CREATE STADIUM
# Creating Stadium
#  CREATE NEW STADIUM
# CREATE MATCH
#
#
# #######################################################################################################
# #                                          NEW MATCH ADDED:                                           #
# #######################################################################################################
#
# dict_match:  {}
#
#
# ######################################################################################################
# #         SAVE CHECKPOINT IN ROUND FILE ROUND_11.json, match=Ind. del Valle~Leones del Norte         #
# ######################################################################################################
#
# END MATCH FUNCTION
#
#
# ######################################################################################################
# #                   NEW EVENT check_points/fixtures/ECUADOR_Liga Pro/ROUND_11.json                   #
# ######################################################################################################
#
#
#
# #######################################################################################################
# #               https://www.flashscore.com/match/tfa67EMi/#/match-summary/match-summary               #
# #######################################################################################################
#
# WAITING DETAILS
# event_info part 1:  {'match_id': '8f673211-3406-4ccf-aacb-bdea8d0bf6f9', 'match_date': '26.04.2026 22:00', 'start_time': '', 'end_time': '', 'name': 'Macara~Libertad', 'home': 'Macara', 'visitor': 'Libertad', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/tfa67EMi/#/match-summary/match-summary', 'place': '', 'country_id': '63n7pzhku1bame5gj', 'match_country': ''}
# Input date format:  26.04.2026 22:00
# event_info end:  {'match_id': '8f673211-3406-4ccf-aacb-bdea8d0bf6f9', 'match_date': datetime.date(2026, 4, 26), 'start_time': datetime.time(21, 0, 0, 17), 'end_time': datetime.time(21, 0, 0, 17), 'name': 'Macara~Libertad', 'home': 'Macara', 'visitor': 'Libertad', 'home_result': '', 'visitor_result': '', 'link_details': 'https://www.flashscore.com/match/tfa67EMi/#/match-summary/match-summary', 'place': '', 'country_id': '63n7pzhku1bame5gj', 'match_country': '', 'tournament_id': '', 'statistic': '{}', 'league_id': '2a60c337-6d3c-418a-94d3-e351b990ce65', 'season_id': '78102a43-27f5-492a-af68-f7adccd61658', 'rounds': 'ROUND_11'}
# FIND TEAM IDs
# ### TEAM NOT FOUND IN LIST OF FILES ######### 'Macara'
# [DB] team_id NOT FOUND: Macara in league 2a60c337-6d3c-418a-94d3-e351b990ce65
# [DB] team_id NOT FOUND: Libertad in league 2a60c337-6d3c-418a-94d3-e351b990ce65
# CREATE STADIUM
# Creating Stadium
#  CREATE NEW STADIUM
# CREATE MATCH
#
#
# #######################################################################################################
# #                                          NEW MATCH ADDED:                                           #
# #######################################################################################################
#
# dict_match:  {}
#
#
# ######################################################################################################
# #                 SAVE CHECKPOINT IN ROUND FILE ROUND_11.json, match=Macara~Libertad                 #
# ######################################################################################################
#
# END MATCH FUNCTION
#
#
# ######################################################################################################
# #                   NEW EVENT check_points/fixtures/ECUADOR_Liga Pro/ROUND_11.json                   #
# ######################################################################################################
#
#
#
# #######################################################################################################
# #               https://www.flashscore.com/match/SU3U1AjT/#/match-summary/match-summary               #
# #######################################################################################################
#
# WAITING DETAILS
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[4], line 2
#       1 # creacion de partidos a futuro "HOCKEY", "TENNIS","GOLF"
# ----> 2 results_fixtures_extraction(driver, ["FOOTBALL","BASKETBALL","BASEBALL", "AM._FOOTBALL"], name_section = 'fixtures')
#
# File ~/work_2026/milestone4.py:898, in results_fixtures_extraction(driver, list_sports, name_section, leagues_subset)
#     895         navigate_through_rounds(driver, league_info, section_name = name_section)
#     897     league_checkpoint = league_info[extract_key]
# --> 898     get_complete_match_info(driver, league_info, dict_league, league_checkpoint, leagues_info_json, section=name_section, li_file=li_file)
#     900 # ACTUALIZAR CONTEO Y DESHABILITAR LIGA AL COMPLETAR
#     901 match_number = get_match_by_league_id(league_info['league_id'])
#
# File ~/work_2026/milestone4.py:562, in get_complete_match_info(driver, league_info, dict_country_league_season, league_checkpoint, leagues_info_json, section, li_file)
#     560 print("WAITING DETAILS")
#     561 wait_load_details(driver, url_details)
# --> 562 event_info = get_match_info(driver, event_info)
#     563 print("event_info part 1: ", event_info)
#     564 event_info['tournament_id'] = ''
#
# File ~/work_2026/milestone4.py:308, in get_match_info(driver, event_info)
#     305 match_info_elements = driver.find_elements(By.XPATH, '//div[@class="matchInfoData"]/div')
#     307 # GET MATCH DATE COMPLETE.
# --> 308 event_info['match_date'] = driver.find_element(By.CLASS_NAME, 'duelParticipant__startTime').text
#     310 for element in match_info_elements:
#     311     print(element.text)
#
# File ~/env/sports_env/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:748, in WebDriver.find_element(self, by, value)
#     745     by = By.CSS_SELECTOR
#     746     value = f'[name="{value}"]'
# --> 748 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~/env/sports_env/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:354, in WebDriver.execute(self, driver_command, params)
#     352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
# --> 354     self.error_handler.check_response(response)
#     355     response["value"] = self._unwrap_value(response.get("value", None))
#     356     return response
#
# File ~/env/sports_env/lib/python3.10/site-packages/selenium/webdriver/remote/errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: Unable to locate element: .duelParticipant__startTime; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:199:5
# NoSuchElementError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:552:5
# dom.find/</<@chrome://remote/content/shared/DOM.sys.mjs:136:16

# %%
# confirm_results(driver, 'fixtures', max_count = 10)

# %% [markdown]
# ## Get players data.

# %%
# obtencion de jugadores
players(driver, ["HOCKEY"])

# %% [markdown]
# # Results extractions Tennis and Golf.

# %%
# actualizcion de partidos tiempo real
# live_games(driver, ["FOOTBALL", "HOCKEY", "BASKETBALL"])
update_lives_matchs(driver)

# %% [markdown]
# # Navegar en todos los resultados encontrados y completar informacion.
